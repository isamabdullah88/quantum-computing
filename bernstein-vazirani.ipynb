# %% [markdown]
# ### Berstein Vazirani Algorithm
# secret string: 0101

# %%
from qiskit import QuantumCircuit
from qiskit.providers.basic_provider import BasicSimulator
from qiskit.visualization import plot_histogram

# %%
circuit = QuantumCircuit(4, 4)

circuit.h([0,1,2,3])
circuit.barrier()

# Oracle
circuit.z([0,2])
circuit.barrier()

circuit.h([0,1,2,3])
circuit.measure([0,1,2,3], [0,1,2,3])

circuit.draw('mpl')

# %%
backend = BasicSimulator()
job = backend.run(circuit, shots=1000)
result = job.result()
stats = result.get_counts()
plot_histogram(stats)

# %% [markdown]
# ### Running on IBM QPU

# %%
# backend = QiskitRuntimeService().get_backend('ibm_osaka')
# sampler = Sampler(backend)
# circuit_tp = transpile(circuit, backend=backend)
# job = sampler.run([circuit_tp], shots=1024)

# %%
# service = QiskitRuntimeService()
# job = service.job(job_id)
# result = job.result()[0]
# stats = result.data.c.get_counts()
# plot_histogram(stats)
